# %% [markdown]
# #📅 Day 9
#
# ##Find Maximum Subarray Sum (Basic Approach)

# %%
arr = [-2, 1, -3, 4, -1, 2, 1, -5, 4]   # sample input

max_sum = arr[0]

for i in range(len(arr)):
    current_sum = 0
    for j in range(i, len(arr)):
        current_sum += arr[j]
        if current_sum > max_sum:
            max_sum = current_sum

print(max_sum)
# Out:
# 6

# %% [markdown]
# ##Find All Subarrays

# %%
arr = [1, 2, 3]   # sample input

for i in range(len(arr)):
    for j in range(i, len(arr)):
        print(arr[i:j+1])
# Out:
# [1]
# [1, 2]
# [1, 2, 3]
# [2]
# [2, 3]
# [3]

# %% [markdown]
# ##Remove Duplicates from Sorted Array

# %%
arr = [1, 1, 2, 2, 3]   # sorted input

result = [arr[0]]

for i in range(1, len(arr)):
    if arr[i] != arr[i - 1]:
        result.append(arr[i])

print(result)
# Out:
# [1, 2, 3]

# %% [markdown]
# ##Merge Two Sorted Lists

# %%
arr1 = [1, 3, 5]   # sample input
arr2 = [2, 4, 6]

result = []
i = j = 0

while i < len(arr1) and j < len(arr2):
    if arr1[i] < arr2[j]:
        result.append(arr1[i])
        i += 1
    else:
        result.append(arr2[j])
        j += 1

result.extend(arr1[i:])
result.extend(arr2[j:])

print(result)
# Out:
# [1, 2, 3, 4, 5, 6]
